# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df1 = pd.read_excel("Superstore_USA.xlsx",sheet_name= 0)
df1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID    Customer Name    Ship Mode Customer Segment Product Category           Product Sub-Category Product Container                                    Product Name  Product Base Margin   Region State or Province       City  Postal Code Order Date  Ship Date    Profit  Quantity ordered new    Sales  Order ID
# 0   18606  Not Specified      0.01        2.88           0.50            2  Janice Fletcher  Regular Air        Corporate  Office Supplies                         Labels         Small Box                                        Avery 49                 0.36  Central          Illinois    Addison        60101 2012-05-28 2012-05-30    1.3200                     2     5.90     88525
# ...

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df2=pd.read_excel("Superstore_USA.xlsx",sheet_name=1)

# %%
df2
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
df3=pd.read_excel("Superstore_USA.xlsx",sheet_name=2)

# %%
df3
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#3......................
a=df1[["Product Name",'Order ID']]
b=df2[["Order ID"]]
pd.merge(a,b,how='inner')
# Out:
#                                          Product Name  Order ID
# 0               Dixon My First Ticonderoga Pencil, #2      9895
# 1                                           Avery 493     13959
# 2                               EcoTones® Memo Sheets     13959
# 3                                           Newell 35     36038
# 4                   Staples SlimLine Pencil Sharpener     39490
# 5                      Hon Non-Folding Utility Tables     39490
# 6   80 Minute Slim Jewel Case CD-R , 10/Pack - Sta...     37760
# 7                                         Accessory34     37760
# 8   Chromcraft Bull-Nose Wood 48" x 96" Rectangula...     37414
# 9                                          Xerox 1983     47265
# 10  Hon 2090 “Pillow Soft” Series Mid Back Swivel/...      7079
# 11      Eureka Recycled Copy Paper 8 1/2" x 11", Ream      7079
# 12                                         Newell 343      8353
# 13        Imation 3.5 IBM Formatted Diskettes, 10/Box      8353
# ...

# %%
#4........................................
k = pd.DataFrame(df1[["Order ID","Product Name"]])
l = pd.DataFrame(df2[["Order ID","Status"]])
pd.merge(k,l)
# Out:
#     Order ID                                       Product Name    Status
# 0       9895              Dixon My First Ticonderoga Pencil, #2  Returned
# 1      13959                                          Avery 493  Returned
# 2      13959                              EcoTones® Memo Sheets  Returned
# 3      36038                                          Newell 35  Returned
# 4      39490                  Staples SlimLine Pencil Sharpener  Returned
# 5      39490                     Hon Non-Folding Utility Tables  Returned
# 6      37760  80 Minute Slim Jewel Case CD-R , 10/Pack - Sta...  Returned
# 7      37760                                        Accessory34  Returned
# 8      37414  Chromcraft Bull-Nose Wood 48" x 96" Rectangula...  Returned
# 9      47265                                         Xerox 1983  Returned
# 10      7079  Hon 2090 “Pillow Soft” Series Mid Back Swivel/...  Returned
# 11      7079      Eureka Recycled Copy Paper 8 1/2" x 11", Ream  Returned
# ...

# %%
#5.................................
len(df1.groupby('Customer Name').count())
# Out:
# 2703

# %%
#6..................................
a = pd.DataFrame(df1["Product Name"].unique())
b = pd.DataFrame(df1[["Region","Product Name"]])
l = pd.DataFrame(df3[["Region","Manager"]])
allmanagers = pd.merge(b,l,on = "Region")
allmanagers
# Out:
#        Region                                       Product Name Manager
# 0     Central                                           Avery 49   Chris
# 1     Central  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...   Chris
# 2     Central                                         Newell 321   Chris
# 3     Central                                         Newell 351   Chris
# 4     Central           OIC Colored Binder Clips, Assorted Sizes   Chris
# ...       ...                                                ...     ...
# 9421    South           Staples Copy Paper (20Lb. and 84 Bright)     Sam
# 9422    South            O'Sullivan 3-Shelf Heavy-Duty Bookcases     Sam
# 9423    South                  Logitech Cordless Access Keyboard     Sam
# 9424    South                      Contemporary Wood/Metal Frame     Sam
# 9425    South  Universal Premium White Copier/Laser Paper (20...     Sam
#
# [9426 rows x 3 columns]

# %%
#7...............................
a= pd.DataFrame(df1["Ship Mode"])
Reg_Air = (len(a[a["Ship Mode"] == "Regular Air"])/len(a))*100
Express_Air=(len(a[a["Ship Mode"]=="Express Air"])/len(a))*100
Delivery_truck=(len(a[a["Ship Mode"]=="Delivery Truck"])/len(a))*100
print(Reg_Air)
print(Express_Air)
print(Delivery_truck)
# Out:
# 74.64460004243581
# 11.744112030553786
# 13.611287927010396

# %%
#8..............................
df1['Delivery_time']=df1["Ship Date"]-df1['Order Date']

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID    Customer Name       Ship Mode Customer Segment Product Category           Product Sub-Category Product Container                                       Product Name  Product Base Margin   Region State or Province        City  Postal Code Order Date  Ship Date       Profit  Quantity ordered new    Sales  Order ID Delivery_time
# 0      18606  Not Specified      0.01        2.88           0.50            2  Janice Fletcher     Regular Air        Corporate  Office Supplies                         Labels         Small Box                                           Avery 49                 0.36  Central          Illinois     Addison        60101 2012-05-28 2012-05-30     1.320000                     2     5.90     88525        2 days
# ...

# %%
#9...............................
df1['Delivery_time']=df1['Delivery_time'].astype(str)
df1["Delivery_time"]=df1["Delivery_time"].str.replace("days",'')
df1["Delivery_time"]=df1['Delivery_time'].astype(int)
df1[df1["Delivery_time"]>10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID            Customer Name       Ship Mode Customer Segment Product Category          Product Sub-Category Product Container                                       Product Name  Product Base Margin   Region State or Province           City  Postal Code Order Date  Ship Date     Profit  Quantity ordered new     Sales  Order ID  Delivery_time
# 643    18246       Critical      0.05       11.09           5.25          250  Brenda Nelson Blanchard     Regular Air        Corporate  Office Supplies                     Envelopes         Small Box                      #10 Self-Seal White Envelopes                 0.36  Central         Minnesota      Richfield        55423 2011-12-29 2012-03-22    58.5000                    19    204.67     87215             84
# ...

# %%
#10........................
a=df1[['Order ID','Delivery_time']]
b=df2[["Order ID"]]
c=pd.merge(b,a,how='inner')
c[c['Delivery_time']>15]
# Out:
# Empty DataFrame
# Columns: [Order ID, Delivery_time]
# Index: []

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID    Customer Name       Ship Mode Customer Segment Product Category           Product Sub-Category Product Container                                       Product Name  Product Base Margin   Region State or Province        City  Postal Code Order Date  Ship Date       Profit  Quantity ordered new    Sales  Order ID  Delivery_time
# 0      18606  Not Specified      0.01        2.88           0.50            2  Janice Fletcher     Regular Air        Corporate  Office Supplies                         Labels         Small Box                                           Avery 49                 0.36  Central          Illinois     Addison        60101 2012-05-28 2012-05-30     1.320000                     2     5.90     88525              2
# ...

# %%
#11
df1.groupby("Region")[['Profit']].sum().iloc[0]
# Out:
# Profit    519825.567067
# Name: Central, dtype: float64

# %%
#12
a=df1.groupby('Region')[['Discount']].sum()
a[a['Discount']==max(a['Discount'])]
# Out:
#          Discount
# Region
# Central    143.06

# %%
#13
a=df1.groupby("Postal Code")['Postal Code'].count()
a
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID    Customer Name       Ship Mode Customer Segment Product Category           Product Sub-Category Product Container                                       Product Name  Product Base Margin   Region State or Province        City  Postal Code Order Date  Ship Date       Profit  Quantity ordered new    Sales  Order ID  Delivery_time
# 0      18606  Not Specified      0.01        2.88           0.50            2  Janice Fletcher     Regular Air        Corporate  Office Supplies                         Labels         Small Box                                           Avery 49                 0.36  Central          Illinois     Addison        60101 2012-05-28 2012-05-30     1.320000                     2     5.90     88525              2
# ...

# %%
a=df1.groupby("Postal Code")['Postal Code'].count()
a
# Out:
# Postal Code
# 1001     1
# 1007     1
# 1013     1
# 1027     1
# 1028     1
#         ..
# 99207    7
# 99301    6
# 99336    6
# 99352    5
# 99362    8
# Name: Postal Code, Length: 1697, dtype: int64

# %%
#14
a=df1.groupby("Customer Segment")[['Profit']].sum()
a[a['Profit']==max(a['Profit'])]
# Out:
#                          Profit
# Customer Segment
# Corporate         505538.627783

# %%
#15
a=df1.groupby("Product Category")[['Profit']].sum()
a[a['Profit']==min(a['Profit'])]
# Out:
#                          Profit
# Product Category
# Furniture         177354.298188

# %%
#16
a=df1.groupby("Product Name")[['Product Base Margin']].sum()
a.sort_values(by='Product Base Margin',ascending=False).iloc[0:10]
# Out:
#                                                     Product Base Margin
# Product Name
# Global High-Back Leather Tilter, Burgundy                         19.98
# BoxOffice By Design Rectangular and Half-Moon M...                18.33
# Bevis 36 x 72 Conference Tables                                   16.38
# Adesso Programmable 142-Key Keyboard                              15.45
# Accessory36                                                       14.11
# Office Star - Mid Back Dual function Ergonomic ...                13.64
# Office Star - Contemporary Task Swivel chair wi...                13.26
# Microsoft Internet Keyboard                                       13.21
# StarTAC 7760                                                      12.98
# Bell Sonecor JB700 Caller ID                                      12.60
